# %%
from lxml import html
import requests
import json
from rdkit import Chem
from rdkit.Chem import MACCSkeys
import csv

# %%
class KEGGCompound:
    def __init__(self, id):
        self.id = id
        self.__molFileText = None
        self.__molFileFetched = False
        #self.mol = None
        self.pathways = []
 
    #
    # Get the SMILES string associated with this compound.
    #
    def getSMILES(self):
        # Use RDKit to convert the mol file string to a SMILES. 
        mol = Chem.MolFromMolBlock(self.fetchMOLFileString())
        try:
            smilesString = Chem.rdmolfiles.MolToSmiles(mol)
        except:
            return("Unhandled")        # This was a polymer, which RDKit can't handle.
        return(smilesString)

    #
    # Get the MACCS fingerprint associated with this compound.
    #
    def getMACCS(self):
        mol = Chem.MolFromMolBlock(self.fetchMOLFileString())
        maccsFp = MACCSkeys.FingerprintMol(mol).ToBitString()
        return(maccsFp)

    #
    #
    #
    def fetchMOLFileString(self):
        if (self.__molFileFetched == True):
            return(self.__molFileText)
        urlStr = "https://www.genome.jp/dbget-bin/www_bget?-f+m+compound+" + self.id
        molFile = requests.get(urlStr)
        self.__molFileText = str(molFile.text)
        self.__molFileFetched = True
        #self.mol = Chem.MolFromMolBlock(self.__molFileText)
        return(self.__molFileText)

    #
    #
    #
    def addPathway(self, mod):
        self.pathways.append(mod)

# %%
import requests

class KEGGPathway:
    def __init__(self, id, name, className):
        self.id = id
        self.name = name
        self.className = className
        self.compounds = []
        self.__compoundsFetched = False

    #
    # REST API URL to get compounds linked to this pathway
    #
    def getCompoundsURL(self):
        return f"https://rest.kegg.jp/link/compound/path:map{self.id}"

    #
    # Fetch a list of KEGGCompound objects associated with this pathway
    #
    def fetchCompounds(self):
        if self.__compoundsFetched:
            return self.compounds

        retval = []
        url = self.getCompoundsURL()
        response = requests.get(url)
        response.raise_for_status()  # raise error if request fails

        # Each line looks like: "path:map00010\tcpd:C00022"
        lines = response.text.strip().splitlines()
        compoundIDs = [line.split("\t")[1].split(":")[1] for line in lines]

        for cid in compoundIDs:
            retval.append(KEGGCompound(cid))  # assuming KEGGCompound class exists

        self.compounds = retval
        self.__compoundsFetched = True
        return retval

# %%
def getPathways():
    retval = []        # This will be a list of KEGGModule objects.
    # Get the KEGG modules page as a string.
    #page = requests.get("https://www.genome.jp/kegg-bin/download_htext?htext=ko00002.keg&format=json&filedir=")
    #jsonFile = open("../../data/kegg-data/ko00002.json")
    #jsonStr = jsonFile.read()
    #jsonFile.close()
    #print(page.text)
    #jsonData = json.loads(jsonStr)
    #print(jsonData.keys())
    #print(type(jsonData))
    #tree = html.fromstring(page.content)

    page = requests.get("https://www.genome.jp/kegg/pathway.html")
    tree = html.fromstring(page.content)
    #.xpath('//div[@id="definition"]/table/tr/td[text()="Reaction"]/../td[2]/a')
    for bNode in tree.xpath('//b'):
        pathwayClassNum = bNode.xpath('text()')[0].split(' ')[0]
        pathwayClassName = bNode.xpath('text()')[0].split(' ')[1]

        if (pathwayClassNum != '1.0' and pathwayClassNum != '1.' and pathwayClassNum != '1.12' and pathwayClassNum[0] == '1'):
            print("b node = " + bNode.xpath('text()')[0])
            print("Pathway class number and name: " + pathwayClassNum + ", " + pathwayClassName)

            # We are interested in this pathway.
            pathwayIDNodes = bNode.xpath('following-sibling::div')[0].xpath('dl/dt')
            for pathwayIDNode in pathwayIDNodes:
                # Get the id.
                pathwayID = pathwayIDNode.xpath('text()')[0]
                pathwayName = pathwayIDNode.xpath('following-sibling::dd/a/text()')[0]
                print("Pathway id and name: " + str(pathwayID) + ", " + str(pathwayName))
                newPathway = KEGGPathway(pathwayID, pathwayName, pathwayClassName)
                retval.append(newPathway)
        #print(tree.xpath('//b/text()'))
    return(retval)

# %%
##################################################################
# MAIN
##################################################################
#compoundDict = {}
#moduleDict = {}


#
# Assemble database of compounds in compoundDict.
#
pathways = getPathways()
print("Number of pathways: " + str(len(pathways)))
#for pw in pathways:
    
#
# Convert the list of modules to a CSV.
#
with open('keggdb2.csv', 'w') as csvfile:
    headers = ['ID', 'SMILES', 'MACCS', 'Pathway ID', 'Pathway name', 'Pathway class']
    writer = csv.DictWriter(csvfile, fieldnames=headers)
    writer.writeheader()
    for mod in pathways:
        print(mod.className + ", " + mod.name + "," + mod.id)
        compounds = mod.fetchCompounds()
        for comp in compounds:
            #print(comp.fetchMOLFileString())
            #print(comp.getSMILES())
    #        print(comp.getMACCS())
    #        smiles = comp.getSMILES()
    #        if (smiles not in compoundDict):
    #            compoundDict[smiles] = comp
            comp.addPathway(mod)
        #for comp in mod.compounds:
            if ("Unhandled" in comp.getSMILES()):
                # Skip this compound, as rdkit can't handle it.
                print("Skipping a compound because RDKit can't handle it.")
                continue
            #if (comp.id in compoundWrittenSet):
            #    continue
            # Indicate that this compound has already been written.
            #compoundWrittenSet.add(comp.id)
            
            #TODO: Write the row for this compound.
            writer.writerow({'ID':comp.id, 'SMILES':comp.getSMILES(), 'MACCS':comp.getMACCS(), 'Pathway ID':mod.id, 'Pathway name':mod.name, 'Pathway class':mod.className })
    
    
            #for modComp in comp.modules:
                #TODO: Append to the modules string some representation of
                # these modules..
            #print(comp.getSMILES() + "," + 
            #print(comp.getMACCS())
# Out:
# b node = 1.1 Carbohydrate metabolism
# Pathway class number and name: 1.1, Carbohydrate
# Pathway id and name: 00010 , Glycolysis / Gluconeogenesis
# Pathway id and name: 00020 , Citrate cycle (TCA cycle)
# Pathway id and name: 00030 , Pentose phosphate pathway
# Pathway id and name: 00040 , Pentose and glucuronate interconversions
# Pathway id and name: 00051 , Fructose and mannose metabolism
# Pathway id and name: 00052 , Galactose metabolism
# Pathway id and name: 00053 , Ascorbate and aldarate metabolism
# Pathway id and name: 00500 , Starch and sucrose metabolism
# Pathway id and name: 00620 , Pyruvate metabolism
# Pathway id and name: 00630 , Glyoxylate and dicarboxylate metabolism
# Pathway id and name: 00640 , Propanoate metabolism
# Pathway id and name: 00650 , Butanoate metabolism
# Pathway id and name: 00660 , C5-Branched dibasic acid metabolism
# Pathway id and name: 00562 , Inositol phosphate metabolism
# b node = 1.2 Energy metabolism
# Pathway class number and name: 1.2, Energy
# Pathway id and name: 00190 , Oxidative phosphorylation
# Pathway id and name: 00195 , Photosynthesis
# Pathway id and name: 00196, Photosynthesis - antenna proteins
# Pathway id and name: 00710 , Carbon fixation by Calvin cycle
# Pathway id and name: 00720 , Other carbon fixation pathways
# Pathway id and name: 00680 , Methane metabolism
# Pathway id and name: 00910 , Nitrogen metabolism
# Pathway id and name: 00920 , Sulfur metabolism
# b node = 1.3 Lipid metabolism
# Pathway class number and name: 1.3, Lipid
# Pathway id and name: 00061 , Fatty acid biosynthesis
# Pathway id and name: 00062 , Fatty acid elongation
# Pathway id and name: 00071 , Fatty acid degradation
# Pathway id and name: 00073, Cutin, suberine and wax biosynthesis
# Pathway id and name: 00074 , Mycolic acid biosynthesis
# Pathway id and name: 00100 , Steroid biosynthesis
# Pathway id and name: 00120 , Primary bile acid biosynthesis
# Pathway id and name: 00121, Secondary bile acid biosynthesis
# Pathway id and name: 00140 , Steroid hormone biosynthesis
# Pathway id and name: 00561 , Glycerolipid metabolism
# Pathway id and name: 00564 , Glycerophospholipid metabolism
# Pathway id and name: 00565 , Ether lipid metabolism
# Pathway id and name: 00600 , Sphingolipid metabolism
# Pathway id and name: 00590, Arachidonic acid metabolism
# Pathway id and name: 00591, Linoleic acid metabolism
# Pathway id and name: 00592 , alpha-Linolenic acid metabolism
# Pathway id and name: 01040 , Biosynthesis of unsaturated fatty acids
# b node = 1.4 Nucleotide metabolism
# Pathway class number and name: 1.4, Nucleotide
# Pathway id and name: 00230 , Purine metabolism
# Pathway id and name: 00240 , Pyrimidine metabolism
# b node = 1.5 Amino acid metabolism
# Pathway class number and name: 1.5, Amino
# Pathway id and name: 00250 , Alanine, aspartate and glutamate metabolism
# Pathway id and name: 00260 , Glycine, serine and threonine metabolism
# Pathway id and name: 00270 , Cysteine and methionine metabolism
# Pathway id and name: 00280 , Valine, leucine and isoleucine degradation
# Pathway id and name: 00290 , Valine, leucine and isoleucine biosynthesis
# Pathway id and name: 00300 , Lysine biosynthesis
# Pathway id and name: 00310 , Lysine degradation
# Pathway id and name: 00220 , Arginine biosynthesis
# Pathway id and name: 00330 , Arginine and proline metabolism
# Pathway id and name: 00340 , Histidine metabolism
# Pathway id and name: 00350 , Tyrosine metabolism
# Pathway id and name: 00360 , Phenylalanine metabolism
# Pathway id and name: 00380 , Tryptophan metabolism
# Pathway id and name: 00400 , Phenylalanine, tyrosine and tryptophan biosynthesis
# b node = 1.6 Metabolism of other amino acids
# Pathway class number and name: 1.6, Metabolism
# Pathway id and name: 00410 , beta-Alanine metabolism
# Pathway id and name: 00430 , Taurine and hypotaurine metabolism
# Pathway id and name: 00440, Phosphonate and phosphinate metabolism
# Pathway id and name: 00450, Selenocompound metabolism
# Pathway id and name: 00460 , Cyanoamino acid metabolism
# Pathway id and name: 00470 , D-Amino acid metabolism
# Pathway id and name: 00480 , Glutathione metabolism
# b node = 1.7 Glycan biosynthesis and metabolism
# Pathway class number and name: 1.7, Glycan
# Pathway id and name: 00520 , Amino sugar and nucleotide sugar metabolism
# Pathway id and name: 00541 , Biosynthesis of various nucleotide sugars
# Pathway id and name: 00510 , N-Glycan biosynthesis
# Pathway id and name: 00513 , Various types of N-glycan biosynthesis
# Pathway id and name: 00512 , Mucin type O-glycan biosynthesis
# Pathway id and name: 00515 , Mannose type O-glycan biosynthesis
# Pathway id and name: 00514, Other types of O-glycan biosynthesis
# Pathway id and name: 00532 , Glycosaminoglycan biosynthesis - chondroitin sulfate / dermatan sulfate
# Pathway id and name: 00534 , Glycosaminoglycan biosynthesis - heparan sulfate / heparin
# Pathway id and name: 00533, Glycosaminoglycan biosynthesis - keratan sulfate
# Pathway id and name: 00531 , Glycosaminoglycan degradation
# Pathway id and name: 00563 , Glycosylphosphatidylinositol (GPI)-anchor biosynthesis
# Pathway id and name: 00601 , Glycosphingolipid biosynthesis - lacto and neolacto series
# Pathway id and name: 00603 , Glycosphingolipid biosynthesis - globo and isoglobo series
# Pathway id and name: 00604 , Glycosphingolipid biosynthesis - ganglio series
# Pathway id and name: 00511, Other glycan degradation
# Pathway id and name: 00540 , Lipopolysaccharide biosynthesis
# Pathway id and name: 00542, O-Antigen repeat unit biosynthesis
# Pathway id and name: 00550, Peptidoglycan biosynthesis
# Pathway id and name: 00552, Teichoic acid biosynthesis
# Pathway id and name: 00571, Lipoarabinomannan (LAM) biosynthesis
# Pathway id and name: 00572 , Arabinogalactan biosynthesis - Mycobacterium
# Pathway id and name: 00543, Exopolysaccharide biosynthesis
# b node = 1.8 Metabolism of cofactors and vitamins
# Pathway class number and name: 1.8, Metabolism
# Pathway id and name: 00730 , Thiamine metabolism
# Pathway id and name: 00740 , Riboflavin metabolism
# Pathway id and name: 00750 , Vitamin B6 metabolism
# Pathway id and name: 00760 , Nicotinate and nicotinamide metabolism
# Pathway id and name: 00770 , Pantothenate and CoA biosynthesis
# Pathway id and name: 00780 , Biotin metabolism
# Pathway id and name: 00785 , Lipoic acid metabolism
# Pathway id and name: 00790 , Folate biosynthesis
# Pathway id and name: 00670 , One carbon pool by folate
# Pathway id and name: 00830, Retinol metabolism
# Pathway id and name: 00860 , Porphyrin metabolism
# Pathway id and name: 00130 , Ubiquinone and other terpenoid-quinone biosynthesis
# b node = 1.9 Metabolism of terpenoids and polyketides
# Pathway class number and name: 1.9, Metabolism
# Pathway id and name: 00900 , Terpenoid backbone biosynthesis
# Pathway id and name: 00902, Monoterpenoid biosynthesis
# Pathway id and name: 00909, Sesquiterpenoid and triterpenoid biosynthesis
# Pathway id and name: 00904 , Diterpenoid biosynthesis
# Pathway id and name: 00906 , Carotenoid biosynthesis
# Pathway id and name: 00905 , Brassinosteroid biosynthesis
# Pathway id and name: 00981, Insect hormone biosynthesis
# Pathway id and name: 00908, Zeatin biosynthesis
# Pathway id and name: 00903, Limonene degradation
# Pathway id and name: 00907, Pinene, camphor and geraniol degradation
# Pathway id and name: 01052, Type I polyketide structures
# Pathway id and name: 00522 , Biosynthesis of 12-, 14- and 16-membered macrolides
# Pathway id and name: 01051, Biosynthesis of ansamycins
# Pathway id and name: 01059 , Biosynthesis of enediyne antibiotics
# Pathway id and name: 01056 , Biosynthesis of type II polyketide backbone
# Pathway id and name: 01057 , Biosynthesis of type II polyketide products
# Pathway id and name: 00253 , Tetracycline biosynthesis
# Pathway id and name: 00523 , Polyketide sugar unit biosynthesis
# Pathway id and name: 01054, Nonribosomal peptide structures
# Pathway id and name: 01053, Biosynthesis of siderophore group nonribosomal peptides
# Pathway id and name: 01055, Biosynthesis of vancomycin group antibiotics
# b node = 1.10 Biosynthesis of other secondary metabolites
# Pathway class number and name: 1.10, Biosynthesis
# Pathway id and name: 00940 , Phenylpropanoid biosynthesis
# Pathway id and name: 00945, Stilbenoid, diarylheptanoid and gingerol biosynthesis
# Pathway id and name: 00941 , Flavonoid biosynthesis
# Pathway id and name: 00944, Flavone and flavonol biosynthesis
# Pathway id and name: 00942, Anthocyanin biosynthesis
# Pathway id and name: 00943 , Isoflavonoid biosynthesis
# Pathway id and name: 00946 , Degradation of flavonoids
# Pathway id and name: 00901 , Indole alkaloid biosynthesis
# Pathway id and name: 00403 , Indole diterpene alkaloid biosynthesis
# Pathway id and name: 00950 , Isoquinoline alkaloid biosynthesis
# Pathway id and name: 00960, Tropane, piperidine and pyridine alkaloid biosynthesis
# Pathway id and name: 00996, Biosynthesis of various alkaloids
# Pathway id and name: 00232 , Caffeine metabolism
# Pathway id and name: 00965 , Betalain biosynthesis
# Pathway id and name: 00966 , Glucosinolate biosynthesis
# Pathway id and name: 00402, Benzoxazinoid biosynthesis
# Pathway id and name: 00311 , Penicillin and cephalosporin biosynthesis
# Pathway id and name: 00332 , Carbapenem biosynthesis
# Pathway id and name: 00261 , Monobactam biosynthesis
# Pathway id and name: 00331 , Clavulanic acid biosynthesis
# Pathway id and name: 00521 , Streptomycin biosynthesis
# Pathway id and name: 00524, Neomycin, kanamycin and gentamicin biosynthesis
# Pathway id and name: 00525 , Acarbose and validamycin biosynthesis
# Pathway id and name: 00401, Novobiocin biosynthesis
# Pathway id and name: 00404 , Staurosporine biosynthesis
# Pathway id and name: 00405 , Phenazine biosynthesis
# Pathway id and name: 00333 , Prodigiosin biosynthesis
# Pathway id and name: 00254 , Aflatoxin biosynthesis
# Pathway id and name: 00998 , Biosynthesis of various antibiotics
# Pathway id and name: 00999 , Biosynthesis of various plant secondary metabolites
# Pathway id and name: 00997 , Biosynthesis of various other secondary metabolites
# b node = 1.11 Xenobiotics biodegradation and metabolism
# Pathway class number and name: 1.11, Xenobiotics
# Pathway id and name: 00362 , Benzoate degradation
# Pathway id and name: 00627 , Aminobenzoate degradation
# Pathway id and name: 00364, Fluorobenzoate degradation
# Pathway id and name: 00625, Chloroalkane and chloroalkene degradation
# Pathway id and name: 00361 , Chlorocyclohexane and chlorobenzene degradation
# Pathway id and name: 00623 , Toluene degradation
# Pathway id and name: 00622 , Xylene degradation
# Pathway id and name: 00633, Nitrotoluene degradation
# Pathway id and name: 00642, Ethylbenzene degradation
# Pathway id and name: 00643, Styrene degradation
# Pathway id and name: 00791, Atrazine degradation
# Pathway id and name: 00930, Caprolactam degradation
# Pathway id and name: 00363, Bisphenol degradation
# Pathway id and name: 00621 , Dioxin degradation
# Pathway id and name: 00626 , Naphthalene degradation
# Pathway id and name: 00624 , Polycyclic aromatic hydrocarbon degradation
# Pathway id and name: 00365, Furfural degradation
# Pathway id and name: 00984, Steroid degradation
# Pathway id and name: 00980, Metabolism of xenobiotics by cytochrome P450
# Pathway id and name: 00982, Drug metabolism - cytochrome P450
# Pathway id and name: 00983, Drug metabolism - other enzymes
# Number of pathways: 170
# Carbohydrate, Glycolysis / Gluconeogenesis,00010
# Carbohydrate, Citrate cycle (TCA cycle),00020
# Carbohydrate, Pentose phosphate pathway,00030
# Carbohydrate, Pentose and glucuronate interconversions,00040
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Carbohydrate, Fructose and mannose metabolism,00051
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Carbohydrate, Galactose metabolism,00052
# Skipping a compound because RDKit can't handle it.
# Carbohydrate, Ascorbate and aldarate metabolism,00053
# Skipping a compound because RDKit can't handle it.
# Carbohydrate, Starch and sucrose metabolism,00500
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Carbohydrate, Pyruvate metabolism,00620
# Carbohydrate, Glyoxylate and dicarboxylate metabolism,00630
# Carbohydrate, Propanoate metabolism,00640
# Carbohydrate, Butanoate metabolism,00650
# Skipping a compound because RDKit can't handle it.
# Carbohydrate, C5-Branched dibasic acid metabolism,00660
# Carbohydrate, Inositol phosphate metabolism,00562
# Energy, Oxidative phosphorylation,00190
# Energy, Photosynthesis,00195
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Energy, Photosynthesis - antenna proteins,00196
# Energy, Carbon fixation by Calvin cycle,00710
# Energy, Other carbon fixation pathways,00720
# Energy, Methane metabolism,00680
# Energy, Nitrogen metabolism,00910
# Energy, Sulfur metabolism,00920
# Skipping a compound because RDKit can't handle it.
# Lipid, Fatty acid biosynthesis,00061
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Lipid, Fatty acid elongation,00062
# Skipping a compound because RDKit can't handle it.
# Lipid, Fatty acid degradation,00071
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Lipid, Cutin, suberine and wax biosynthesis,00073
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Lipid, Mycolic acid biosynthesis,00074
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
# Lipid, Steroid biosynthesis,00100
# Lipid, Primary bile acid biosynthesis,00120
# Lipid, Secondary bile acid biosynthesis,00121
# Lipid, Steroid hormone biosynthesis,00140
# Lipid, Glycerolipid metabolism,00561
# Skipping a compound because RDKit can't handle it.
# Lipid, Glycerophospholipid metabolism,00564
# Lipid, Ether lipid metabolism,00565
# Lipid, Sphingolipid metabolism,00600
# Lipid, Arachidonic acid metabolism,00590
# Lipid, Linoleic acid metabolism,00591
# Lipid, alpha-Linolenic acid metabolism,00592
# Lipid, Biosynthesis of unsaturated fatty acids,01040
# Nucleotide, Purine metabolism,00230
# Skipping a compound because RDKit can't handle it.
# Skipping a compound because RDKit can't handle it.
